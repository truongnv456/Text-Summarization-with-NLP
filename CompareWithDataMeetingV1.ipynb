# %% [markdown]
# <a href="https://colab.research.google.com/github/ngockhanh5110/nlp-vietnamese-text-summarization/blob/main/notebooks/inferencing_vietnews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Overview: The code below is for the purpose of comparing the quality of the algorithms Lsa, KL, LexRank, TextRank, SumBasic, Luhn with the model I trained**

# %% [markdown]
# # **Connect to drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Install lib**

# %%
# !pip install vncorenlp datasets==1.0.2
# !pip install transformers
# !pip install dill==0.3.5.1
# Out:
# Requirement already satisfied: vncorenlp in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: datasets==1.0.2 in /usr/local/lib/python3.10/dist-packages (1.0.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==1.0.2) (1.22.4)
# Requirement already satisfied: pyarrow>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from datasets==1.0.2) (9.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from datasets==1.0.2) (0.3.5.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==1.0.2) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==1.0.2) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from datasets==1.0.2) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets==1.0.2) (3.12.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==1.0.2) (3.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==1.0.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==1.0.2) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==1.0.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==1.0.2) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==1.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==1.0.2) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets==1.0.2) (1.16.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: dill==0.3.5.1 in /usr/local/lib/python3.10/dist-packages (0.3.5.1)

# %%
# !pip install git-python==1.0.3
# !pip install sacrebleu==1.4.12
# !pip install rouge_score
# Out:
# Requirement already satisfied: git-python==1.0.3 in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.10/dist-packages (from git-python==1.0.3) (3.1.32)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython->git-python==1.0.3) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython->git-python==1.0.3) (5.0.0)
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.22.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.65.0)

# %%
import os
new_path = "/content/drive/MyDrive/LLM_TEXT/"
os.chdir(new_path)
current_path = os.getcwd()
print("current path:", current_path)
# Out:
# current path: /content/drive/MyDrive/LLM_TEXT

# %%
import glob
import pandas as pd
import concurrent.futures
from datasets import *
import datasets
import transformers
import nltk
nltk.download('punkt')

from transformers import RobertaTokenizerFast,AutoTokenizer
from seq2seq_trainer import Seq2SeqTrainer
from transformers import TrainingArguments
from dataclasses import dataclass, field
from typing import Optional
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !pip install sumy
# Out:
# Requirement already satisfied: sumy in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from sumy) (0.6.2)
# Requirement already satisfied: breadability>=0.1.20 in /usr/local/lib/python3.10/dist-packages (from sumy) (0.1.20)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from sumy) (2.27.1)
# Requirement already satisfied: pycountry>=18.2.23 in /usr/local/lib/python3.10/dist-packages (from sumy) (22.3.5)
# Requirement already satisfied: nltk>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from sumy) (3.8.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from breadability>=0.1.20->sumy) (4.0.0)
# Requirement already satisfied: lxml>=2.0 in /usr/local/lib/python3.10/dist-packages (from breadability>=0.1.20->sumy) (4.9.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.0.2->sumy) (4.65.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycountry>=18.2.23->sumy) (67.7.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->sumy) (3.4)

# %% [markdown]
# # **Processing data**

# %%
size_data_test = 10

# %%
def listPaths(path):
  pathfiles = list()
  cnt = 0
  for pathfile in glob.glob(path):
    cnt += 1
    pathfiles.append(pathfile)
    if cnt == size_data_test:
       break
  return pathfiles

test_paths = listPaths('/content/drive/MyDrive/LLM_TEXT/dataset/meeting/*.txt')
for file in test_paths:
  print(file)
# Out:
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/002.txt
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/012.txt
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/021.txt
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/030.txt
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/019.txt
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/011.txt
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/005.txt
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/020.txt
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/016.txt
# /content/drive/MyDrive/LLM_TEXT/dataset/meeting/029.txt

# %%
def read_content(path_file):
  """
  Input: Path of txt file
  Output
  """

  # print("\n\n path_file:", path_file)
  summary_content = ""
  summary_task = ""
  original = ""

  with open(path_file, "r", encoding="utf-8") as file:
      lines  = file.readlines()
      cnt = 0
      for line in lines:
          line = line.strip()

          if line.startswith("NOI_DUNG_TOM_TAT"):
              cnt = 1
              line = line.replace("NOI_DUNG_TOM_TAT", "")
              line = line.replace(":", "")
          elif line.startswith("NHIEM_VU"):
              cnt = 2
              line = line.replace("NHIEM_VU", "")
              line = line.replace(":", "")
          elif line.startswith("NOI_DUNG_GOC"):
              cnt = 3
              line = line.replace("NOI_DUNG_GOC", "")
              line = line.replace(":", "")
          if line:
            if cnt == 1:
              summary_content += line
            elif cnt == 2:
              summary_task += line
            elif cnt == 3:
              original += line

  # print("summary_content:", summary_content)
  # print("summary_task:", summary_task)
  # print("original:", original)
  return {'file' : path_file,
          'summary_task': summary_task,
          'summary_content': summary_content,
          'original': original}

# %%
def get_stop_words_vn(path):
    ret = []
    # path = "/content/drive/MyDrive/LLM_TEXT/vietnamese-stopwords-dash.txt"
    f = open(path, "r")
    lines = f.readlines()
    for line  in lines:
       line = line.replace("_", " ")
       line = " " + line.replace("\n", "") + " "
       ret.append(line)
    return ret

stop_words = get_stop_words_vn("/content/drive/MyDrive/LLM_TEXT/vietnamese-stopwords-dash.txt")
task_words = get_stop_words_vn("/content/drive/MyDrive/LLM_TEXT/vietnamese-task-dash.txt")
# print("stop_words", stop_words)
print("task_words", task_words)
# Out:
# task_words [' nhiệm vụ ', ' đảm nhiệm vai trò ', ' đảm nhận vai trò ', ' đảm nhận công việc ', ' đảm nhiệm nhiệm vụ ', ' được phân công việc ', ' được giao công việc ', ' đã giao cho ', ' phụ trách công việc ', ' sẽ giao công việc ', ' sẽ phân công việc ', ' phân công công việc ', ' sẽ tiến hành ', ' đảm nhận ']

# %%
import nltk
from nltk import sent_tokenize
# nltk.download('punkt')

def process_content_sentences( body: str, min_length=5, max_length=50):
        # for word in reversed(stop_words):
        #   body.replace(word, " ")
        sents = [s.strip() for s in sent_tokenize(body)]
        return [c for c in sents if max_length > len(c.split(" ")) > min_length]

def detectTask(str):
  sentences = process_content_sentences(str, 1, 400)
  ret = ""
  for sentence in sentences:
    sentence = sentence.lower()
    for wTask in task_words:
      if wTask.strip() in sentence:
        # for word in reversed(stop_words):
        #   sentence = sentence.replace(word, " ")
        for word in reversed(stop_words):
          sentence = sentence.replace(word, " ")
        # print(sentence)
        ret += sentence
        break
  return ret

# %%
txt = read_content("/content/drive/MyDrive/LLM_TEXT/dataset/meeting/023.txt")
print("summary_task: ", txt["summary_task"])
print ("result: ",detectTask(txt["summary_task"]))
# Out:
# summary_task:  Tú hoàn thành một phần công việc và đã gửi bản thiết kế sơ bộ cho mọi người xem qua qua email.Huy do hoàn cảnh gia đình, tôi không thể làm việc đúng tiến độ. Hiện tại, tôi đã hoàn thành 70% thiết kế trang chủ và sẽ gửi bản tóm tắt cho mọi người trong vòng 24 giờ tớTrọng sẽ tổ chức một cuộc họp nhỏ sau cuộc họp này để xác định lịch trình và phân công công việc. Trang thiết kế giao diện lịch sử giao dịch trên trang web quản lý chi tiêu.   Giao diện lịch sử giao dịch nên hiển thị danh sách các giao dịch trước đây của người dùng, kèm theo thông tin chi tiết và tiện ích tìm kiếm. Thời hạn  hoàn thành trong vòng 7 ngày.Huy  Nhiệm vụ  Thiết kế giao diện quản lý tài khoản trên trang web quản lý chi tiêu. Thời gian trong vòng  12 ngày .Trọng sẽ tiến hành giao việc thiết kế giao diện thông tin cá nhân của người dùng cho trang web quản lý chi tiêu, đã chuẩn bị một mô tả công việc chi tiết.Tú sẽ thiết kế trang cá nhân cho người dùng. Giao diện này nên cho phép người dùng cập nhật thông tin cá nhân, xem lịch sử giao dịch và quản lý các tài khoản liên quan đến trang web, hoàn thành nhiệm vụ này trong vòng 10 ngàyTrang sẽ thiết kế giao diện lịch sử giao dịch. Giao diện này nên hiển thị danh sách các giao dịch trước đây của người dùng, kèm theo thông tin chi tiết và tiện ích tìm kiếm., hoàn thành nhiệm vụ này trong vòng 7 ngày..Huy sẽ là người thiết kế giao diện quản lý tài khoản. Giao diện này nên cho phép người dùng thêm, sửa đổi và xóa tài khoản của họ, cũng như quản lý thông tin liên quan.
# result:  hiện tại, hoàn thành 70% thiết kế trang chủ gửi tóm tắt vòng 24 tớtrọng tổ chức họp họp xác định lịch trình phân công công việc.thời hạn  hoàn thành vòng 7 ngày.huy  nhiệm vụ  thiết kế giao diện quản lý tài khoản trang web quản lý chi tiêu.thời gian vòng  12 .trọng tiến hành giao thiết kế giao diện thông trang web quản lý chi tiêu, mô tả công chi tiết.tú thiết kế trang dùng.giao diện phép cập nhật thông cá nhân, lịch sử giao dịch quản lý tài khoản trang web, hoàn thành nhiệm vụ vòng 10 ngàytrang thiết kế giao diện lịch sử giao dịch.giao diện hiển thị danh sách giao dịch dùng, kèm thông chi tiết tiện ích kiếm., hoàn thành nhiệm vụ vòng 7 ngày..huy thiết kế giao diện quản lý tài khoản.

# %%
def get_dataframe(pathfiles):
  with concurrent.futures.ProcessPoolExecutor() as executor:
    data = executor.map(read_content, pathfiles)

  # Make blank dataframe
  data_df = list()
  for d in data:
    data_df.append(d)
  data_df = pd.DataFrame(data_df)
  data_df.dropna(inplace = True)
  data_df = data_df.sample(frac=1).reset_index(drop=True)

  return data_df

# %%
test_df = get_dataframe(test_paths)
print ("test_df", test_df["summary_task"], test_df["summary_content"] )
# Out:
# test_df 0    Phương sẽ đảm nhận vai trò chính trong việc th...
# 1    Đơn vị quản lý A phụ trách công việc phân tích...
# 2    Hà  sẽ tiến hành xây dựng  kế hoạch bài dạy đư...
# 3    Tuấn đã  thiết kế và hoàn thiện một số phần củ...
# 4    Linh: Chủ tọa cuộc họp, giao việc cho các thàn...
# 5    Đồng chí Hà  sẽ tiến hành xây dựng  kế hoạch b...
# 6    Quyên sẽ đảm nhận vai trò chính trong việc thi...
# 7    Chủ tịch công đoàn :  Tiến hành xây dựng  kế h...
# 8    Lam sẽ đảm nhận vai trò chính trong việc phát ...
# 9    Đồng chí chủ tịch công đoàn  sẽ tiến hành xây ...
# Name: summary_task, dtype: object 0    Trong cuộc họp giao nhiệm vụ của công ty Vạn H...
# 1    Dưới đây là phân công công việc cho dự án thiế...
# 2    Phân công công việc cho việc xây dựng chuyên đ...
# 3    Báo cáo tiến độ thiết kế giao diện cho trang w...
# 4    Trong cuộc họp giao việc cho ba thành viên tro...
# 5    Phân công công việc cho việc xây dựng chuyên đ...
# 6    Cuộc họp giao nhiệm vụ của công ty Việt á, chú...
# 7    Phân công công nhiệm vụ  cho việc xây dựng côn...
# 8    Phân công nhiệm vụ code chức năng review cho h...
# 9    Phân công công nhiệm vụ  cho việc xây dựng côn...
# Name: summary_content, dtype: object

# %%
test_data =  Dataset.from_pandas(test_df)

# %%
# load rouge for validation
rouge = datasets.load_metric("rouge")

# %% [markdown]
# # **Inference**

# %%
path_result = "/content/drive/MyDrive/LLM_TEXT/inference/infer_2/"
RATIO = 0.2
listAlorithms = ['KLSummarizer','LexRankSummarizer','LsaSummarizer','LuhnSummarizer','SumBasicSummarizer','TextRankSummarizer']
models = listAlorithms
rouge1_recall = []
rouge1_precision = []
rouge1_f1 = []
rouge2_recall = []
rouge2_precision = []
rouge2_f1 = []
rougel_recall = []
rougel_precision = []
rougel_f1 = []

# %%
def getRougeMyModel(rouge_output):
   for key,value in rouge_output.items():
      if key == "rouge1":
         rouge1_recall.append(value.mid[0])
         rouge1_precision.append(value.mid[1])
         rouge1_f1.append(value.mid[2])
         print('rouge1:recall', value.mid[0],"-precision",value.mid[1],'-F1-Score',value.mid[2])
      elif key == "rouge2":
         rouge2_recall.append(value.mid[0])
         rouge2_precision.append(value.mid[1])
         rouge2_f1.append(value.mid[2])
         print('rouge2:recall', value.mid[0],"-precision",value.mid[1],'-F1-Score',value.mid[2])
      elif key == "rougeL":
         rougel_recall.append(value.mid[0])
         rougel_precision.append(value.mid[1])
         rougel_f1.append(value.mid[2])
         print('rougeL:recall', value.mid[0],"-precision",value.mid[1],'-F1-Score',value.mid[2])

# %% [markdown]
# ## **With my model**

# %%
myModelName = 'Custom "Custom PhoBERT"'

# %%
import datasets
from transformers import RobertaTokenizer, EncoderDecoderModel, AutoTokenizer
from sklearn.model_selection import train_test_split


tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base", use_fast=False)

model = EncoderDecoderModel.from_pretrained('/content/drive/MyDrive/LLM_TEXT/trainning_summary_content_bbch/checkpoint-8000')
model.to("cpu")
batch_size = 32  # change to 64 for full evaluation

# map data correctly
def generate_summary(batch):
    # Tokenizer will automatically set [BOS] <text> [EOS]
    inputs = tokenizer(batch["original"], padding="max_length", truncation=True, max_length=256, return_tensors="pt")
    input_ids = inputs.input_ids.to("cpu")
    attention_mask = inputs.attention_mask.to("cpu")

    outputs = model.generate(input_ids, attention_mask=attention_mask)

    # all special tokens including will be removed
    output_str = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    batch["pred"] = output_str

    return batch
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# The following encoder weights were not tied to the decoder ['roberta/pooler']
# The following encoder weights were not tied to the decoder ['roberta/pooler']

# %%
results = test_data.map(generate_summary, batched=True, batch_size=batch_size, remove_columns=["original"])

result_summary_content = results["pred"]
summary_content_original = results["summary_content"]
summary_task_original = results["summary_task"]


print ("result_summary_content: ",result_summary_content[0] )

print ("file: ",test_data[0]["file"]  )
print ("summary_conten: ",summary_content_original[0] )
print ("summary_task: ",summary_task_original[0] )
print ("original: ",test_data[0]["original"] )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1369: UserWarning: Using `max_length`'s default (32) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
#   0%|          | 0/1 [00:00<?, ?ba/s]
# result_summary_content:  Trong cuộc họp giao nhiệm vụ của công ty Vạn Hoa đã quyết định phân công nhiệm vụ code trang web quản lý nhân sự cho năm thành viên trong
# file:  /content/drive/MyDrive/LLM_TEXT/dataset/meeting/012.txt
# summary_conten:  Trong cuộc họp giao nhiệm vụ của công ty Vạn Hoa đã quyết định phân công nhiệm vụ code trang web quản lý nhân sự cho năm thành viên trong nhóm.
# summary_task:  Phương sẽ đảm nhận vai trò chính trong việc thiết kế giao diện người dùng (UI) và trang chủ. Nhiệm vụ của Phương sẽ là thiết kế giao diện người dùng cho trang web quản lý nhân sự, bao gồm trang chủ hiển thị thông tin tổng quan và các thành phần UI cần thiết.Anh  sẽ được giao các nhiệm vụ sau: xây dựng chức năng quản lý nhân viên. Nhiệm vụ: Phát triển chức năng quản lý nhân viên, bao gồm thêm/xóa/sửa thông tin nhân viên, tìm kiếm và sắp xếp danh sách nhân viên.Linh sẽ đảm nhận nhiệm vụ xây dựng chức năng quản lý bộ phận, Thiết kế và triển khai chức năng quản lý bộ phận, bao gồm tạo/biên tập/xóa bộ phận, hiển thị danh sách bộ phận, và phân loại nhân viên theo bộ phận.Dương sẽ đảm nhận vai trò xây dựng chức năng quản lý công việc. Xây dựng chức năng quản lý công việc của nhân viên, bao gồm tạo/biên tập/xóa công việc, giao việc cho nhân viên, và hiển thị danh sách công việc.Ngọc sẽ đảm nhận vai trò kiểm thử và tối ưu hóa trang web quản lý nhân sự. Nhiệm vụ cụ thể của anh ta bao gồm: Kiểm tra tính đúng đắn và độ tương thích trên các trình duyệt và thiết bị khác nhau. Tối ưu hóa hiệu suất và tốc độ tải trang của trang web.
# original:  Trong cuộc họp giao nhiệm vụ của chúng ta, chúng ta đã quyết định phân công nhiệm vụ code trang web quản lý nhân sự cho năm thành viên trong nhóm. Dưới đây là phân công cụ thể và deadline cho mỗi thành viên: Phương sẽ đảm nhận vai trò chính trong việc thiết kế giao diện người dùng (UI) và trang chủ. Nhiệm vụ của Phương sẽ là thiết kế giao diện người dùng cho trang web quản lý nhân sự, bao gồm trang chủ hiển thị thông tin tổng quan và các thành phần UI cần thiết.Anh  sẽ được giao các nhiệm vụ sau: xây dựng chức năng quản lý nhân viên. Nhiệm vụ: Phát triển chức năng quản lý nhân viên, bao gồm thêm/xóa/sửa thông tin nhân viên, tìm kiếm và sắp xếp danh sách nhân viên.Linh sẽ đảm nhận nhiệm vụ xây dựng chức năng quản lý bộ phận, Thiết kế và triển khai chức năng quản lý bộ phận, bao gồm tạo/biên tập/xóa bộ phận, hiển thị danh sách bộ phận, và phân loại nhân viên theo bộ phận.Dương sẽ đảm nhận vai trò xây dựng chức năng quản lý công việc. Xây dựng chức năng quản lý công việc của nhân viên, bao gồm tạo/biên tập/xóa công việc, giao việc cho nhân viên, và hiển thị danh sách công việc.Ngọc sẽ đảm nhận vai trò kiểm thử và tối ưu hóa trang web quản lý nhân sự. Nhiệm vụ cụ thể của anh ta bao gồm: Kiểm tra tính đúng đắn và độ tương thích trên các trình duyệt và thiết bị khác nhau. Tối ưu hóa hiệu suất và tốc độ tải trang của trang web. Chúng ta sẽ thiết lập các cuộc họp định kỳ để theo dõi tiến độ và giải quyết các vấn đề nảy sinh trong quá trình phát triển. Để đảm bảo hoàn thành dự án đúng hạn, các thành viên được khuyến khích trình bày ý kiến, cùng nhau giải quyết khó khăn, và tuân thủ deadline được đề ra.

# %%
result_summary_task = []
for data in test_df["original"]:
  ret_task = detectTask(data)
  result_summary_task.append(ret_task)
  print("data", data)
  print('--->',ret_task, "\n")
# Out:
# data Trong cuộc họp giao nhiệm vụ của chúng ta, chúng ta đã quyết định phân công nhiệm vụ code trang web quản lý nhân sự cho năm thành viên trong nhóm. Dưới đây là phân công cụ thể và deadline cho mỗi thành viên: Phương sẽ đảm nhận vai trò chính trong việc thiết kế giao diện người dùng (UI) và trang chủ. Nhiệm vụ của Phương sẽ là thiết kế giao diện người dùng cho trang web quản lý nhân sự, bao gồm trang chủ hiển thị thông tin tổng quan và các thành phần UI cần thiết.Anh  sẽ được giao các nhiệm vụ sau: xây dựng chức năng quản lý nhân viên. Nhiệm vụ: Phát triển chức năng quản lý nhân viên, bao gồm thêm/xóa/sửa thông tin nhân viên, tìm kiếm và sắp xếp danh sách nhân viên.Linh sẽ đảm nhận nhiệm vụ xây dựng chức năng quản lý bộ phận, Thiết kế và triển khai chức năng quản lý bộ phận, bao gồm tạo/biên tập/xóa bộ phận, hiển thị danh sách bộ phận, và phân loại nhân viên theo bộ phận.Dương sẽ đảm nhận vai trò xây dựng chức năng quản lý công việc. Xây dựng chức năng quản lý công việc của nhân viên, bao gồm tạo/biên tập/xóa công việc, giao việc cho nhân viên, và hiển thị danh sách công việc.Ngọc sẽ đảm nhận vai trò kiểm thử và tối ưu hóa trang web quản lý nhân sự. Nhiệm vụ cụ thể của anh ta bao gồm: Kiểm tra tính đúng đắn và độ tương thích trên các trình duyệt và thiết bị khác nhau. Tối ưu hóa hiệu suất và tốc độ tải trang của trang web. Chúng ta sẽ thiết lập các cuộc họp định kỳ để theo dõi tiến độ và giải quyết các vấn đề nảy sinh trong quá trình phát triển. Để đảm bảo hoàn thành dự án đúng hạn, các thành viên được khuyến khích trình bày ý kiến, cùng nhau giải quyết khó khăn, và tuân thủ deadline được đề ra.
# ---> trong họp giao nhiệm vụ ta, quyết định phân công nhiệm vụ code trang web quản lý nhân thành viên nhóm.dưới phân công deadline thành viên: phương đảm vai trò thiết kế giao diện (ui) trang chủ.nhiệm vụ phương thiết kế giao diện trang web quản lý nhân sự, bao trang chủ hiển thị thông tổng quan thành ui thiết.anh  giao nhiệm vụ sau: xây dựng chức năng quản lý nhân viên.nhiệm vụ: phát triển chức năng quản lý nhân viên, bao thêm/xóa/sửa thông nhân viên, kiếm xếp danh sách nhân viên.linh đảm nhiệm vụ xây dựng chức năng quản lý phận, thiết kế triển khai chức năng quản lý phận, bao tạo/biên tập/xóa phận, hiển thị danh sách phận, phân nhân viên phận.dương đảm vai trò xây dựng chức năng quản lý công việc.xây dựng chức năng quản lý công nhân viên, bao tạo/biên tập/xóa công việc, giao nhân viên, hiển thị danh sách công việc.ngọc đảm vai trò kiểm thử tối ưu hóa trang web quản lý nhân sự.nhiệm vụ bao gồm: kiểm tra đắn độ tương trình duyệt thiết nhau.
#
# data Dưới đây là phân công công việc cho dự án thiết kế trang web bán hàng, được giao cho 4 đơn vị quản lý và 2 người. Các công việc được xác định theo độ ưu tiên, có tên công việc, mô tả và thời gian thực hiện từ ngày nào đến ngày nào: Đơn vị quản lý A phụ trách công việc phân tích yêu cầu khách hàng. Mô tả: Đơn vị quản lý A sẽ tiến hành phân tích và hiểu rõ yêu cầu của khách hàng về trang web bán hàng. Họ sẽ tạo một bản tóm tắt yêu cầu chi tiết để định hình phạm vi dự án. Thời gian thực hiện: Từ ngày 1/6 đến ngày 5/6.Đơn vị quản lý B phụ trách công việc thiết kế giao diện người dùng (UI) Mô tả: Đơn vị quản lý B sẽ thiết kế giao diện người dùng hấp dẫn và dễ sử dụng cho trang web bán hàng. Họ sẽ tạo các mẫu giao diện, chọn màu sắc, biểu tượng và cải thiện trải nghiệm người dùng. Thời gian thực hiện: Từ ngày 2/6 đến ngày 8/6. Đơn vị quản lý C phụ trách công việc: Phát triển chức năng và cơ sở dữ liệu. Mô tả: Đơn vị quản lý C sẽ phát triển các chức năng cần thiết và xây dựng cơ sở dữ liệu cho trang web bán hàng. Họ sẽ xác định các chức năng như giỏ hàng, thanh toán và quản lý sản phẩm, cũng như thiết kế và triển khai cơ sở dữ liệu. Thời gian thực hiện: Từ ngày 5/6 đến ngày 15/6. Đơn vị quản lý D phụ trách công việc: Kiểm thử và tối ưu hóa. Mô tả: Đơn vị quản lý D sẽ thực hiện kiểm thử và tối ưu hóa trang web bán hàng để đảm bảo hoạt động ổn định và tối ưu. Họ sẽ tìm và khắc phục các lỗi, kiểm tra tương thích trên các trình duyệt và thiết bị khác nhau. Thời gian thực hiện: Từ ngày 12/6 đến ngày 20/6Long phụ trách công việc: Tạo nội dung và hình ảnh. Mô tả: Long sẽ tạo nội dung hấp dẫn và mô tả sản phẩm cho trang web bán hàng. Họ cũng sẽ chọn và sắp xếp hình ảnh phù hợp để tăng tính thẩm mỹ và thu hút khách hàng. Thời gian thực hiện: Từ ngày 1/6 đến ngày 10/6. Linh phụ trách công việc: Triển khai và đưa vào hoạt động. Mô tả: Linh sẽ triển khai trang web bán hàng và đưa nó vào hoạt động. Họ sẽ cài đặt các yêu cầu kỹ thuật, kiểm tra tính năng và đảm bảo trang web hoạt động một cách ổn định trước khi ra mắt. Thời gian thực hiện: Từ ngày 15/6 đến ngày 25/6. Các thành viên được yêu cầu hoàn thành công việc đúng thời hạn để đảm bảo tiến độ dự án và chất lượng trang web bán hàng.
# ---> dưới phân công công dự án thiết kế trang web hàng, giao 4 quản lý 2 người.các công xác định độ ưu tiên, công việc, mô tả nào: quản lý a phụ trách công phân tích hàng.mô tả: quản lý a tiến hành phân tích hàng trang web hàng.thời gian thực hiện: 1/6 5/6.đơn vị quản lý b phụ trách công thiết kế giao diện (ui) mô tả: quản lý b thiết kế giao diện hấp trang web hàng.đơn vị quản lý c phụ trách công việc: phát triển chức năng sở liệu.đơn vị quản lý d phụ trách công việc: kiểm thử tối ưu hóa.thời gian thực hiện: 12/6 20/6long phụ trách công việc: nội dung hình ảnh.linh phụ trách công việc: triển khai hoạt động.
#
# data Dưới đây là phân công công việc cho việc xây dựng chuyên đề môn địa lí lớp 7 bài :Dải đồng bằng duyên hải miền Trung của tổ xã hôi trường THCS Nguyễn Văn Huyên . Nội dung đề bám sát trong sách giáo khoa  đồng thời có thêm một số  kiến thức mở rộng về dải đồng bằng duyên hải miền Trung . Mô tả: Đồng chí Hà  sẽ tiến hành xây dựng  kế hoạch bài dạy đưa ra các hoạt động  dạy học phù hợp với nội dung của từng yêu cầu mà SGK đề cập đến., Thời gian thực hiện: Từ ngày 11/3 đến ngày 14/3.Đồng chí Hùng tìm các bản đồ lược  đồ , tranh . thước phim minh hoạ liên quan đến đặc điểm tự nhiên, khí hậu , sông ngòi và con người của dải đồng bằng duyên hải miền Trung  có liên quan đến các hoạt động dạy học mà đồng chí Hà đã lên kế hoạch.Thời gian thực hiện: Từ ngày 14/3 đến ngày 15/5. Đồng chí  Trà  sẽ tiến hành thiết kế bài giảng trên powerpoint.  Thời gian thực hiện: ngày 16/3.. Tâm  phụ trách công việc: Kiểm tra và soát lỗi nội dung của Hà, Hùng, Trà đã thực hiện: Từ ngày 15/3 đến ngày 16/3 Cuối cùng cả tổ sẽ thống nhất sửa đổi hay bổ sung thêm nội dung cho chuyên đề vào 16h30 ngày 17/3.Đề nghị các đồng chí thực hiện đúng  yêu cầu đã được phân công và  hoàn thành công việc đúng thời hạn để đảm bảo chất lượng cho chuyên đề xây dựng tiết dạy địa lý : Dải đồng bằng duyên Hải miền Trung. Chúng ta sẽ thiết lập các cuộc họp định kỳ để theo dõi tiến độ và giải quyết các vấn đề nảy sinh trong quá trình phát triển. Để đảm bảo hoàn thành và đánh giá kết quả học tập của  học sinh đúng thời gian quy định đề nghi các các thành viên tong được khuyến khích trình bày ý kiến, cùng nhau giđóng góp ý kiến để có bộ đề kiểm tra chất lượng
# ---> dưới phân công công xây dựng chuyên đề môn địa lí lớp 7 :dải đồng duyên hải miền trung tổ xã hôi trường thcs nguyễn văn huyên .mô tả: đồng chí hà  tiến hành xây dựng  kế hoạch dạy hoạt động  dạy học nội dung sgk đề cập đến., thực hiện: 11/3 14/3.đồng chí hùng đồ lược  đồ , tranh .đồng chí  trà  tiến hành thiết kế giảng powerpoint.thời gian thực hiện: 16/3.. tâm  phụ trách công việc: kiểm tra soát lỗi nội dung hà, hùng, trà thực hiện: 15/3 16/3 tổ thống sửa đổi bổ sung nội dung chuyên đề 16h30 17/3.đề nghị đồng chí  phân công  hoàn thành công thời hạn chất chuyên đề xây dựng tiết dạy địa lý : dải đồng duyên hải miền trung.
#
# data Trọng: Xin chào mọi người! Cảm ơn vì đã có mặt trong buổi họp ngày hôm nay.ngày 2//2023 Chúng ta sẽ bắt đầu báo cáo tiến độ thiết kế giao diện cho trang web quản lý chi tiêu. Trước hết, tôi xin tóm tắt lại công việc đã được giao và chúng ta sẽ nghe báo cáo từ từng thành viên.Tuấn: Xin chào mọi người, tôi sẽ bắt đầu. Từ khi chúng ta bắt đầu dự án, tôi đã tiến hành nghiên cứu thiết kế giao diện, thu thập ý kiến từ người dùng tiềm năng và tạo một bản thiết kế ban đầu dựa trên những thông tin đó. Tuy nhiên, do các rào cản kỹ thuật, tôi đã gặp một số khó khăn và chưa hoàn thành được thiết kế cuối cùng. Tôi xin lỗi vì sự chậm trễ này.Thúy: Điều đó không sao, Tuấn. Chúng ta hiểu rằng tai nạn làm bạn gặp trở ngại không mong muốn. Nhưng có gì bạn đã hoàn thành cho đến nay?Tuấn: Tôi đã thiết kế và hoàn thiện một số phần của giao diện, bao gồm trang đăng nhập và trang chính hiển thị thông tin tổng quan về chi tiêu. Các phần này đã được đánh giá tích cực bởi nhóm người dùng thử nghiệm. Tuy nhiên, vẫn còn một số phần nhỏ chưa hoàn thành như trang quản lý danh mục và trang tạo giao dịch mới.Tùng: Tôi xin lỗi vì không thể hoàn thành công việc của mình. Vì tai nạn, tôi không thể làm việc trong thời gian dự kiến. Tuy nhiên, tôi đã cố gắng hoàn thành phần của mình bằng cách làm việc từ xa và cập nhật tiến độ qua email.Trọng: Xin lưu ý rằng chúng ta hiểu và đồng thông những khó khăn mà Tuấn và Tùng đã gặp phải. Chúng ta rất biết ơn sự nỗ lực của các bạn trong dự án này. Các bạn còn gặp khó khăn gì nữa không?Thúy: Về phần của mình, tôi đã hoàn thành thiết kế giao diện cho trang xem chi tiết giao dịch và trang báo cáo thống kê. Những phần này đã được Tuấn kiểm tra và đánh giá tích cực. Tôi cũng đã gửi các tài liệu liên quan cho Tuấn để anh ta có thể tiếp tục công việc.Trọng: Cảm ơn, Thúy. Vậy với tình hình hiện tại, chúng ta cần phải thống nhất lịch trình và điều chỉnh công việc. Tuấn, chúng ta sẽ đánh giá những phần mà bạn đã hoàn thành và xác định một kế hoạch hoàn thiện từ phần còn lại. Tùng, bạn có thể chia sẻ với chúng ta các khả năng làm việc của mình để chúng ta có thể phối hợp và hoàn thiện dự án một cách tốt nhất không?Tùng: Tất nhiên, Trọng. Tôi đã bắt đầu khỏe hơn và sẵn lòng đóng góp vào dự án. Chúng ta có thể thảo luận và tìm cách phối hợp công việc để hoàn thành thiết kế giao diện.Trọng: Rất tốt! Chúng ta sẽ cùng nhau hoàn thiện thiết kế giao diện cho trang web quản lý chi tiêu. Tuấn, chúng ta sẽ liên hệ với nhau sau cuộc họp này để xác định kế hoạch cụ thể. Còn lại, chúng ta sẽ tiếp tục làm việc và gửi thông báo tiến độ qua email hàng tuần.Tuấn: Đồng ý. Tôi sẽ cung cấp bản tóm tắt tiến độ cho mọi người trong vòng 24 giờ.Thúy: Tuyệt! Chúng ta sẽ giữ li
iến hành xây dựng  kế hoạch bài dạy đưa ra các hoạt động  dạy học phù hợp với nội dung của từng yêu cầu mà SGK đề cập đến., Thời gian thực hiện: Từ ngày 11/3 đến ngày 14/3.Đồng chí Hùng tìm các bản đồ lược  đồ , tranh . thước phim minh hoạ liên quan đến đặc điểm tự nhiên, khí hậu , sông ngòi và con người của dải đồng bằng duyên hải miền Trung  có liên quan đến các hoạt động dạy học mà đồng chí Hà đã lên kế hoạch.Thời gian thực hiện: Từ ngày 14/3 đến ngày 15/5. Đồng chí  Trà  sẽ tiến hành thiết kế bài giảng trên powerpoint.  Thời gian thực hiện: ngày 16/3.. Tâm  phụ trách công việc: Kiểm tra và soát lỗi nội dung của Hà, Hùng, Trà đã thực hiện: Từ ngày 15/3 đến ngày 16/3 Cuối cùng cả tổ sẽ thống nhất sửa đổi hay bổ sung thêm nội dung cho chuyên đề vào 16h30 ngày 17/3.Đề nghị các đồng chí thực hiện đúng  yêu cầu đã được phân công và  hoàn thành công việc đúng thời hạn để đảm bảo chất lượng cho chuyên đề xây dựng tiết dạy địa lý : Dải đồng bằng duyên Hải miền Trung. Cuối cùng cả tổ sẽ thống nhất sửa đổi hay bổ sung thêm nội dung cho chuyên đề vào 16h30 ngày 17/3.Đề nghị các đồng chí thực hiện đúng  yêu cầu đã được phân công và  hoàn thành công việc đúng thời hạn để đảm bảo chất lượng cho chuyên đề xây dựng tiết dạy địa lý : Dải đồng bằng duyên Hải miền Trung. C
# ---> dưới phân công công xây dựng chuyên đề môn địa lí lớp 7 :dải đồng duyên hải miền trung tổ xã hôi trường thcs nguyễn văn huyên .mô tả: đồng chí hà  tiến hành xây dựng  kế hoạch dạy hoạt động  dạy học nội dung sgk đề cập đến., thực hiện: 11/3 14/3.đồng chí hùng đồ lược  đồ , tranh .đồng chí  trà  tiến hành thiết kế giảng powerpoint.thời gian thực hiện: 16/3.. tâm  phụ trách công việc: kiểm tra soát lỗi nội dung hà, hùng, trà thực hiện: 15/3 16/3 tổ thống sửa đổi bổ sung nội dung chuyên đề 16h30 17/3.đề nghị đồng chí  phân công  hoàn thành công thời hạn chất chuyên đề xây dựng tiết dạy địa lý : dải đồng duyên hải miền trung.
#
# data Trong cuộc họp giao nhiệm vụ của công ty xây dưng Việt Á  chúng ta đã quyết định phân công nhiệm vụ thiết kế căn hộ dành cho nhóm bao gồm 4 thành viên. Dưới đây là phân công cụ thể và deadline cho mỗi thành viên: Quyên sẽ đảm nhận vai trò chính trong việc thiết kế kiến trúc và bố cục căn hộ. Nhiệm vụ của Quyên bao gồm: Tạo bản vẽ thiết kế kiến trúc tổng quan cho căn nhà, bao gồm bố cục sơ đồ các phòng, kích thước tổng quan, và vị trí cửa, cửa sổ . Deadline: 1 tuần từ ngày hôm nay. Chi sẽ đảm nhận nhiệm vụ thiết kế nội thất và lựa chọn vật liệu. nhiệm vụ: Đề xuất các ý tưởng về nội thất, gồm lựa chọn vật liệu, màu sắc, thiết kế các phòng riêng biệt như phòng khách, phòng ngủ, phòng bếp, và phòng tắm. Hùng ta sẽ thực hiện các công việc sau: thiết kế hệ thống điện và nước. Nhiệm vụ: Xác định và thiết kế hệ thống điện và nước cho căn nhà, bao gồm các điểm điện,
Chúng ta sẽ thiết lập các cuộc họp định kỳ để theo dõi tiến độ và giải quyết các vấn đề nảy sinh trong quá trình phát triển. Để đảm bảo hoàn thành dự án đúng hạn, các thành viên được khuyến khích trình bày ý kiến, cùng nhau giải quyết khó khăn và tuân thủ deadline được đề ra.
# ---> ngày 20/6/2023 diễn họp giao nhiệm vụ củ công ty thắng ta, quyết định phân công nhiệm vụ code chức năng review hai thành viên nhóm.dưới phân công deadline thành viên: lam đảm vai trò phát triển giao diện (ui) chức năng review.nhiệm vụ bao gồm: thiết kế giao diện món hiển thị hiện có.ngọc  đảm nhiệm vụ lưu trữ liệu backend.deadline: 1 tuần thành viên lam hoàn thành nhiệm vụ mình.
#
# data Để  thực hiện tốt nhiệm vụ năm học 2022- 2023 ,trong tháng 9 này nhà trường đề ra một số các hoạt động . Sau đây  là phân công công nhiệm vụ  cho việc xây dựng công tác tháng 9 năm học 2022- 2023 của trường TH Đặng Trần Côn B .Nội dung công việc  bám sát nhiệm vụ năm học  do BGD  sở giáo dục và đào tạo Hà Nội chi đạo . BGH quyết định dao 1 số công việc cho các đồng chí trong ban Hội đồng trường chỉ đạo các hoạt động, công việc do mình phụ trách . Mô tả: Đồng chí chủ tịch công đoàn  sẽ tiến hành xây dựng  kế hoạch nhiệm vụ của công đoàn như chăm lo đời sống cán bộ giáo viên,nhân viên của nhà trường , lập kế hoạch hoạt động cho việc hội nghị cán bô công chức.  Thời gian thực hiện  từ 5/9  đến 20/9. Các đồng chí tô trưởng chuyên môn chỉ  đạo các thành viên trong tổ thực hiện đúng chương trình các môn học theo thời khoá biểu được phân công ,lập kế hoạch cho các thành viên trong tổ thống nhất kế hoạch dạy học sao cho các hoạt động  dạy học phù hợp với nội dung của từng yêu cầu mà SGK đề cập đến., Thời gian thực hiện: Từ ngày 5/9 đến ngày 20/9.Các đồng chí GV chủ nhiệm xây dựng kế hoạch của lớp , họp cha mẹ học sinh vào ngày 21/9 đêt thống nhất với phụ huynh các hoạt động dạy và học của cô và trò trong năm học . Thời gian thực hiện từ 5/9 đến 31/9Các đồng chí giáo viên bộ môn xây dựng kế hoạch  bài dạy của môn do mình phụ trách theo đúng chương trình thời khóa biểu., dạy học phải tạo cho học sinh hứng khởi học tập , học mà chơi, chơi mà học  Đồng chí tổng phụ trách xây dựng kế hoạch của liên đội  cụ thể như phân công các chi đội chăm sóc công trình măng non, lập kế hoạch đại hội chi đội, liên đội, xây dựng các hoạt động chào mừng năm học mới . Thời gian từ 5/9 đến 24/9. Các đồng chí của tổ văn phòng tiếp nhận  các thông tin chi đạo của cấp trên chuyển đến ban giám hiệu.,tiếp nhận hồ sơ chuyên đi , chuyên đến của học sinh. Xây dựng được thư viện với nhiều đầu sách phong phú để thu hút  được giáo viên và học sinh đến với thư viện đọc và tìm hiểu về sách ,báo , truyện. Thời gian từ 5/9 đến 15/9Đề nghị các tổ  thực hiện đúng  yêu cầu đã được phân công và  hoàn thành công việc đúng thời hạn để đảm bảo chất lượng cho các hoạt đông của nhà trường . Tân thành cảm  ơn các đồng chí
# ---> để  nhiệm vụ học 2022- 2023 ,trong 9 trường đề hoạt động .sau  phân công công nhiệm vụ  xây dựng công tác 9 học 2022- 2023 trường th đặng trần côn b .nội dung công  bám sát nhiệm vụ học  bgd  sở giáo dục đào hà nội chi đạo .mô tả: đồng chí chủ tịch công đoàn  tiến hành xây dựng  kế hoạch nhiệm vụ công đoàn chăm lo đời sống cán giáo viên,nhân viên trường , lập kế hoạch hoạt động hội nghị cán bô công chức.

# %% [markdown]
# ## **Inference data with algorithms** [Lsa, KL, LexRank, TextRank, SumBasic, Luhn]

# %%
import os
import re

def write_data(folder, offset, index, content):
  path = folder+"/summary_{:06d}.txt".format(offset+index+1)
  f = open(path, "w")
  f.write(content)
  f.close()

def folderExist(folder_path):
  if not os.path.exists(folder_path):
      os.makedirs(folder_path)

def clean_text(text):
  text = text.replace("\n"," ")
  text = re.sub("\s\s+"," ",text)
  text = text.replace("TP.", "TP")
  text = re.sub("\.\.+",".",text)
  text = re.sub("…",".",text)
  all_number = re.findall("\d*\.\d+",text)
  all_dot = re.findall("[A-Z|Ê|Ư|Ơ|Â|Ă|Đ]\s*\.", text)
  text_dot = re.findall("\.\s+[^A-Z|Ê|Ư|Ơ|Â|Ă|Đ]", text)
  for w in all_number:
    text = text.replace(w, w.replace(".",""))
  for w in all_dot:
    text = text.replace(w, w.replace(".",""))
  for w in text_dot:
    text = text.replace(w, w.replace(".",""))
  text = re.sub(r"[()\"#@:<>{}`+=~|!“”]", "", text)
  print("allnumber:",all_number)
  print("all_dot",all_dot)
  print('text_dot:',text_dot)
  return text

def load_sum(model, content, index):
  name_model = str(type(model)).split(".")[-1].replace("'>","")
  result = ''
  path = path_result + name_model
  folderExist(path)
  lenght = len(parser.document.sentences)
  count = 1 if RATIO * lenght < 1 else lenght * RATIO
  for sentence in model(content, count):
      result += str(sentence) +" "
  write_data(path, 0, idx, result)

# %%
class TokenizerVNVal:
    @staticmethod
    def to_sentences(text: str):
        return [s.strip() for s in text.split(".")]
    @staticmethod
    def to_words(sentence: str):
        # sentence = sentence.replace("_", " ")
        return [w.strip() for w in sentence.split(" ")]

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer
from sumy.summarizers.kl import KLSummarizer
from sumy.summarizers.lex_rank import LexRankSummarizer
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.summarizers.text_rank import TextRankSummarizer
from sumy.summarizers.sum_basic import SumBasicSummarizer
from sumy.utils import get_stop_words
import nltk

SENTENCES_COUNT = 3
path_file_stopword = "/content/drive/MyDrive/LLM_TEXT/vietnamese-stopwords-dash.txt"
# print(test_df)
if __name__ == "__main__":

    # or for plain text files
    # parser = PlaintextParser.from_file("document.txt", Tokenizer(LANGUAGE))
    # parser = PlaintextParser.from_string("Check this out.", Tokenizer(LANGUAGE))
    lsaSummarizer = LsaSummarizer()
    lsaSummarizer.stop_words = get_stop_words_vn(path_file_stopword)
    kLSummarizer = KLSummarizer()
    kLSummarizer.stop_words = get_stop_words_vn(path_file_stopword)
    lexRankSummarizer = LexRankSummarizer()
    lexRankSummarizer.stop_words = get_stop_words_vn(path_file_stopword)
    luhnSummarizer = LuhnSummarizer()
    luhnSummarizer.stop_words = get_stop_words_vn(path_file_stopword)
    textRankSummarizer = TextRankSummarizer()
    textRankSummarizer.stop_words = get_stop_words_vn(path_file_stopword)
    sumBasicSummarizer = SumBasicSummarizer()
    sumBasicSummarizer.stop_words = get_stop_words_vn(path_file_stopword)
    for idx, originnalTxt in enumerate(test_df["original"]):
        print(idx)
        parser = PlaintextParser.from_string(clean_text(originnalTxt), TokenizerVNVal)
        load_sum(lsaSummarizer, parser.document, idx)
        load_sum(kLSummarizer, parser.document, idx)
        load_sum(lexRankSummarizer, parser.document, idx)
        load_sum(textRankSummarizer, parser.document, idx)
        load_sum(luhnSummarizer, parser.document, idx)
        load_sum(sumBasicSummarizer, parser.document, idx)


    # for sentence in summarizer(parser.document, SENTENCES_COUNT):
    #     print(sentence)
# Out:
# 0
# allnumber: []
# all_dot []
# text_dot: []
# 1
# allnumber: []
# all_dot []
# text_dot: []
# 2
# allnumber: []
# all_dot []
# text_dot: ['. t']
# 3
# allnumber: []
# all_dot []
# text_dot: []
# 4
# allnumber: []
# all_dot []
# text_dot: []
# 5
# allnumber: []
# all_dot []
# text_dot: ['. t']
# 6
# allnumber: []
# all_dot []
# text_dot: ['. n']
# 7
# allnumber: []
# all_dot []
# text_dot: ['. c']
# 8
# allnumber: []
# all_dot []
# text_dot: []
# 9
# allnumber: []
# all_dot ['B .']
# text_dot: []

# %%
from sumy.parsers.plaintext import PlaintextParser
from statistics import mean, median

def get_data_evalue(folder, offset, count):
  data = []
  for i in range(count):
    path = folder + "/summary_{:06d}.txt".format(i+offset+1)
    f = open(path, "r")
    lines = f.readlines()
    sum = ""
    for line in lines:
        sum += line.replace("_"," ") + " "
    sum = sum.replace("\n","")
    sum = sum.replace("<q>"," ")
    sum = sum.lower()
    data.append(sum)
  return data

def evalue(model):
    path_sum = path_result +"/" +  model
    data_sum = get_data_evalue(path_sum, 0, size_data_test)
    r1_recall = []
    r1_precision = []
    r1_f = []

    r2_recall= []
    r2_precision = []
    r2_f = []
    rl_sent = []
    rl_sum = []

    print("model: ", model)
    ret_rouge_ = rouge.compute(predictions=data_sum, references=summary_content_original, rouge_types=["rouge1","rouge2","rougeL"])
    # for key,value in ret_rouge_.items():
    #   print(key)
    #   print(value.mid)

    getRougeMyModel(ret_rouge_)

# %%
rouge1_recall = []
rouge1_precision = []
rouge1_f1 = []
rouge2_recall = []
rouge2_precision = []
rouge2_f1 = []
models = listAlorithms
for model in models:
  if model != myModelName:
    evalue(model)


# getRougeMyModel()
# Out:
# model:  KLSummarizer
# rouge1:recall 0.3547976377305474 -precision 0.8411342342731314 -F1-Score 0.47300195910879195
# rouge2:recall 0.20653431442905554 -precision 0.5475979742284091 -F1-Score 0.28133901061028826
# rougeL:recall 0.2682847317808159 -precision 0.6588677407384502 -F1-Score 0.3603378815194491
# model:  LexRankSummarizer
# rouge1:recall 0.25884900513662157 -precision 0.8981153582597281 -F1-Score 0.37501362034976926
# rouge2:recall 0.16307111950623976 -precision 0.600617642248077 -F1-Score 0.23475145647979895
# rougeL:recall 0.1953984837984536 -precision 0.7067370946903351 -F1-Score 0.28365521803180627
# model:  LsaSummarizer
# rouge1:recall 0.3011610662522765 -precision 0.8868199008917723 -F1-Score 0.41787372469954115
# rouge2:recall 0.15853288540423235 -precision 0.5462517773387339 -F1-Score 0.22651486297624288
# rougeL:recall 0.19956130656785198 -precision 0.6292566263698449 -F1-Score 0.28098068739803556
# model:  LuhnSummarizer
# rouge1:recall 0.19470329487824106 -precision 0.9043093776037673 -F1-Score 0.3068903688746605
# rouge2:recall 0.11731328941068421 -precision 0.6123883164100556 -F1-Score 0.18807451749340398
# rougeL:recall 0.1497053886165382 -precision 0.7373975662685625 -F1-Score 0.23832289107059157
# model:  SumBasicSummarizer
# rouge1:recall 0.3578316774856719 -precision 0.7808958104601368 -F1-Score 0.4514408999213729
# rouge2:recall 0.17858038262951736 -precision 0.48118551183768576 -F1-Score 0.2380116390521957
# rougeL:recall 0.23982951492934262 -precision 0.5826515129151071 -F1-Score 0.3103898278417987
# model:  TextRankSummarizer
# rouge1:recall 0.19706412230153642 -precision 0.9057128304460165 -F1-Score 0.31031381414295683
# rouge2:recall 0.12050581007430614 -precision 0.6041789699398394 -F1-Score 0.19191253866013475
# rougeL:recall 0.1525049803629362 -precision 0.7385257410023112 -F1-Score 0.24227735192815852

# %% [markdown]
# # **Evaluation**

# %%
print("Evaluation content")
rouge_summary_content = rouge.compute(predictions=result_summary_content, references=summary_content_original, rouge_types=["rouge1","rouge2","rougeL"])
models.append(myModelName)
getRougeMyModel(rouge_summary_content)
# Out:
# Evaluation content
# rouge1:recall 0.8154225680720246 -precision 0.8356124539500931 -F1-Score 0.8159453230952733
# rouge2:recall 0.7236644875504591 -precision 0.7296064351499134 -F1-Score 0.7205561052622558
# rougeL:recall 0.749969806763285 -precision 0.7630472630531699 -F1-Score 0.7461707805600557

# %%
print("Evaluation task")
rouge_summary_task = rouge.compute(predictions=result_summary_task, references=summary_task_original, rouge_types=["rouge1","rouge2","rougeL"])
for key,value in rouge_summary_task.items():
  print(key)
  print(value.mid)
# Out:
# Evaluation task
# rouge1
# Score(precision=0.924469784973088, recall=0.5383246296913506, fmeasure=0.6585567529095)
# rouge2
# Score(precision=0.6182357033747964, recall=0.354826890525198, fmeasure=0.4349039340591933)
# rougeL
# Score(precision=0.6595647308751704, recall=0.3851866240824054, fmeasure=0.46992897931008326)

# %% [markdown]
# # **Draw a comparison chart**

# %%
import matplotlib.pyplot as plt
x = np.arange(len(models))
width = 0.1
plt.figure(figsize=(10, 6))
plt.bar(x, rouge1_recall, width, label='Rouge-1 Recall')
plt.bar(x + width, rouge1_precision, width, label='Rouge-1 Precision')
plt.bar(x + 2 * width, rouge1_f1, width, label='Rouge-1 F1-Score')
plt.bar(x + 3 * width, rouge2_recall, width, label='Rouge-2 Recall')
plt.bar(x + 4 * width, rouge2_precision, width, label='Rouge-2 Precision')
plt.bar(x + 5 * width, rouge2_f1, width, label='Rouge-2 F1-Score')
plt.xlabel('Chart of meeting content with model and algorithm [Lsa, KL, LexRank, TextRank, SumBasic, Luhn]')
plt.ylabel('Score')
plt.title('Rouge Scores')
plt.xticks(x + 2 * width, models, rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
rouge1_recall_task = []
rouge1_precision_task = []
rouge1_f1_task = []
rouge2_recall_task = []
rouge2_precision_task = []
rouge2_f1_task = []
models_task = ["Content in task"]
for key,value in rouge_summary_task.items():
      if key == "rouge1":
         rouge1_recall_task.append(value.mid[0])
         rouge1_precision_task.append(value.mid[1])
         rouge1_f1_task.append(value.mid[2])
         print('rouge1:recall', value.mid[0],"-precision",value.mid[1],'-F1-Score',value.mid[2])
      elif key == "rouge2":
         rouge2_recall_task.append(value.mid[0])
         rouge2_precision_task.append(value.mid[1])
         rouge2_f1_task.append(value.mid[2])
         print('rouge2:recall', value.mid[0],"-precision",value.mid[1],'-F1-Score',value.mid[2])
      elif key == "rougeL":
         rougel_recall.append(value.mid[0])
         rougel_precision.append(value.mid[1])
         rougel_f1.append(value.mid[2])
         print('rougeL:recall', value.mid[0],"-precision",value.mid[1],'-F1-Score',value.mid[2])
# Out:
# rouge1:recall 0.924469784973088 -precision 0.5383246296913506 -F1-Score 0.6585567529095
# rouge2:recall 0.6182357033747964 -precision 0.354826890525198 -F1-Score 0.4349039340591933
# rougeL:recall 0.6595647308751704 -precision 0.3851866240824054 -F1-Score 0.46992897931008326

# %%
import matplotlib.pyplot as plt
x = np.arange(len(models_task))
width = 0.1
plt.figure(figsize=(10, 6))
plt.bar(x, rouge1_recall_task, width, label='Rouge-1 Recall')
plt.bar(x + width, rouge1_precision_task, width, label='Rouge-1 Precision')
plt.bar(x + 2 * width, rouge1_f1_task, width, label='Rouge-1 F1-Score')
plt.bar(x + 3 * width, rouge2_recall_task, width, label='Rouge-2 Recall')
plt.bar(x + 4 * width, rouge2_precision_task, width, label='Rouge-2 Precision')
plt.bar(x + 5 * width, rouge2_f1_task, width, label='Rouge-2 F1-Score')
plt.xlabel('')
plt.ylabel('Score')
plt.title('Rouge Scores')
plt.xticks(x + 2 * width, models_task, rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
